# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\Customer-ProjectData.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                      53.0       Kentucky    L       Gray  Winter
# 1                      64.0          Maine    L     Maroon  Winter
# ...

# %%
flt = df.select_dtypes(include = ['float'])
flt
# Out:
#       Purchase Amount (USD)  Review Rating  Previous Purchases
# 0                      53.0            3.1                14.0
# 1                      64.0            3.1                 2.0
# 2                      73.0            3.1                23.0
# 3                      90.0            3.5                49.0
# 4                      49.0            2.7                31.0
# ...                     ...            ...                 ...
# 3895                   28.0            4.2                32.0
# 3896                   49.0            4.5                41.0
# 3897                   33.0            2.9                24.0
# 3898                   77.0            3.8                24.0
# 3899                   81.0            3.1                33.0
#
# [3900 rows x 3 columns]

# %%
for i in flt:
    df[i] = df[i].fillna(df[i].mean())
    print(df[i])
# Out:
# 0       53.0
# 1       64.0
# 2       73.0
# 3       90.0
# 4       49.0
#         ...
# 3895    28.0
# 3896    49.0
# 3897    33.0
# 3898    77.0
# 3899    81.0
# Name: Purchase Amount (USD), Length: 3900, dtype: float64
# 0       3.1
# 1       3.1
# 2       3.1
# 3       3.5
# 4       2.7
#        ...
# 3895    4.2
# 3896    4.5
# 3897    2.9
# 3898    3.8
# 3899    3.1
# Name: Review Rating, Length: 3900, dtype: float64
# 0       14.0
# 1        2.0
# 2       23.0
# 3       49.0
# 4       31.0
#         ...
# 3895    32.0
# 3896    41.0
# 3897    24.0
# 3898    24.0
# 3899    33.0
# Name: Previous Purchases, Length: 3900, dtype: float64

# %%
df.isna().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    1
# Item Purchased            1
# Category                  1
# Purchase Amount (USD)     0
# Location                  3
# Size                      1
# Color                     1
# Season                    2
# Review Rating             0
# Subscription Status       0
# Shipping Type             1
# Discount Applied          1
# Promo Code Used           2
# Previous Purchases        0
# Payment Method            2
# Frequency of Purchases    0
# dtype: int64

# %%
obj = df.select_dtypes(include = ['object'])
obj
# Out:
#       Gender Item Purchased     Category       Location Size      Color  \
# 0       Male         Blouse     Clothing       Kentucky    L       Gray
# 1       Male        Sweater     Clothing          Maine    L     Maroon
# 2       Male          Jeans     Clothing  Massachusetts    S     Maroon
# 3       Male        Sandals     Footwear   Rhode Island    M     Maroon
# 4       Male         Blouse     Clothing         Oregon    M  Turquoise
# ...      ...            ...          ...            ...  ...        ...
# 3895  Female         Hoodie     Clothing       Virginia    L  Turquoise
# 3896  Female       Backpack  Accessories           Iowa    L      White
# 3897  Female           Belt  Accessories     New Jersey    L      Green
# 3898  Female          Shoes     Footwear      Minnesota    S      Brown
# 3899  Female        Handbag  Accessories     California    M      Beige
#
#       Season Subscription Status   Shipping Type Discount Applied  \
# ...

# %%
for i in obj:
    df[i] = df[i].fillna(df[i].mode()[0])
    print(df[i])
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 3895    Female
# 3896    Female
# 3897    Female
# 3898    Female
# 3899    Female
# Name: Gender, Length: 3900, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item Purchased'
# ...

# %%
df.isna().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.select_dtypes('float').columns
# Out:
# Index(['Purchase Amount (USD)', 'Review Rating', 'Previous Purchases'], dtype='object')

# %%
df.to_csv(r"D:\SLA\Python\customer_data.csv",index = False)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                      53.0       Kentucky    L       Gray  Winter
# 1                      64.0          Maine    L     Maroon  Winter
# ...

# %%
df.rename(columns={'Customer ID':'Customer_Id','Item Purchased':'Item_Purchased','Purchase Amount (USD)':'Purchase_Amount(USD)','Review Rating':'Review_Rating','Subscription Status':'Subscription_Status','Shipping Type':'Shipping_Type','Discount Applied':'Discount_Applied','Promo Code Used':'Promo_Code_Used','Previous Purchases':'Previous_Purchases','Payment Method':'Payment_Method','Frequency of Purchases':'Frequency_of_Purchases'},inplace = True)
df
# Out:
#       Customer ID  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount(USD)       Location Size      Color  Season  \
# 0                     53.0       Kentucky    L       Gray  Winter
# 1                     64.0          Maine    L     Maroon  Winter
# ...

# %%
df.rename(columns={'Customer ID':'Customer_id'},inplace = True)
df
# Out:
#       Customer_id  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount(USD)       Location Size      Color  Season  \
# 0                     53.0       Kentucky    L       Gray  Winter
# 1                     64.0          Maine    L     Maroon  Winter
# ...

# %%
df.to_csv(r"D:\SLA\Python\customer_data.csv",index = False)
df
# Out:
#       Customer_id  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount(USD)       Location Size      Color  Season  \
# 0                     53.0       Kentucky    L       Gray  Winter
# 1                     64.0          Maine    L     Maroon  Winter
# ...

# %%
df.rename(columns={'Purchase_Amount(USD)':'Purchase_Amount_USD'},inplace = True)
df
# Out:
#       Customer_id  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                    53.0       Kentucky    L       Gray  Winter
# 1                    64.0          Maine    L     Maroon  Winter
# ...

# %%
df.to_csv(r"D:\SLA\Python\customer_data.csv",index = False)

# %%
df.isnull().sum()
# Out:
# Customer_id                0
# Age                        0
# Gender                     0
# Item_Purchased             1
# Category                   1
# Purchase_Amount_USD        2
# Location                   3
# Size                       1
# Color                      1
# Season                     2
# Review_Rating             38
# Subscription_Status        0
# Shipping_Type              1
# Discount_Applied           1
# Promo_Code_Used            2
# Previous_Purchases         1
# Payment_Method             2
# Frequency_of_Purchases     0
# dtype: int64

# %%
df.dtypes
# Out:
# Customer_id                 int64
# Age                         int64
# Gender                     object
# Item_Purchased             object
# Category                   object
# Purchase_Amount_USD       float64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review_Rating             float64
# Subscription_Status        object
# Shipping_Type              object
# Discount_Applied           object
# Promo_Code_Used            object
# Previous_Purchases        float64
# Payment_Method             object
# Frequency_of_Purchases     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Customer_id', 'Age', 'Gender', 'Item_Purchased', 'Category',
#        'Purchase_Amount_USD', 'Location', 'Size', 'Color', 'Season',
#        'Review_Rating', 'Subscription_Status', 'Shipping_Type',
#        'Discount_Applied', 'Promo_Code_Used', 'Previous_Purchases',
#        'Payment_Method', 'Frequency_of_Purchases'],
#       dtype='object')

# %%
flt = df.select_dtypes('float')
flt
# Out:
#       Purchase_Amount_USD  Review_Rating  Previous_Purchases
# 0                    53.0            3.1                14.0
# 1                    64.0            3.1                 2.0
# 2                    73.0            3.1                23.0
# 3                    90.0            3.5                49.0
# 4                    49.0            2.7                31.0
# ...                   ...            ...                 ...
# 3895                 28.0            4.2                32.0
# 3896                 49.0            4.5                41.0
# 3897                 33.0            2.9                24.0
# 3898                 77.0            3.8                24.0
# 3899                 81.0            3.1                33.0
#
# [3900 rows x 3 columns]

# %%
plt.subplots(1,3,figsize = (15,5))
plt.subplot(1,3,1)
plt.title('Purchase Amount (USD)')
plt.hist(df['Purchase_Amount_USD'],color = "#45a818")
plt.subplot(1,3,2)
plt.title('Review rating')
plt.hist(df['Review_Rating'],color = '#1878a8')
plt.subplot(1,3,3)
plt.title('Previous purchases')
plt.hist(df['Previous_Purchases'],color = '#18a878')
# Out:
# (array([424., 360., 395., 382., 404., 386., 402., 382., 371., 393.]),
#  array([ 1. ,  5.9, 10.8, 15.7, 20.6, 25.5, 30.4, 35.3, 40.2, 45.1, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
for i in flt:
    df[i] = df[i].fillna(df[i].mean())
    print(df[i])
# Out:
# 0       53.0
# 1       64.0
# 2       73.0
# 3       90.0
# 4       49.0
#         ...
# 3895    28.0
# 3896    49.0
# 3897    33.0
# 3898    77.0
# 3899    81.0
# Name: Purchase_Amount_USD, Length: 3900, dtype: float64
# 0       3.1
# 1       3.1
# 2       3.1
# 3       3.5
# 4       2.7
#        ...
# 3895    4.2
# 3896    4.5
# 3897    2.9
# 3898    3.8
# 3899    3.1
# Name: Review_Rating, Length: 3900, dtype: float64
# 0       14.0
# 1        2.0
# 2       23.0
# 3       49.0
# 4       31.0
#         ...
# 3895    32.0
# 3896    41.0
# 3897    24.0
# 3898    24.0
# 3899    33.0
# Name: Previous_Purchases, Length: 3900, dtype: float64

# %%
df.isna().sum()
# Out:
# Customer_id               0
# Age                       0
# Gender                    0
# Item_Purchased            1
# Category                  1
# Purchase_Amount_USD       0
# Location                  3
# Size                      1
# Color                     1
# Season                    2
# Review_Rating             0
# Subscription_Status       0
# Shipping_Type             1
# Discount_Applied          1
# Promo_Code_Used           2
# Previous_Purchases        0
# Payment_Method            2
# Frequency_of_Purchases    0
# dtype: int64

# %%
obj = df.select_dtypes(include = ['object'])
obj
# Out:
#       Gender Item_Purchased     Category       Location Size      Color  \
# 0       Male         Blouse     Clothing       Kentucky    L       Gray
# 1       Male        Sweater     Clothing          Maine    L     Maroon
# 2       Male          Jeans     Clothing  Massachusetts    S     Maroon
# 3       Male        Sandals     Footwear   Rhode Island    M     Maroon
# 4       Male         Blouse     Clothing         Oregon    M  Turquoise
# ...      ...            ...          ...            ...  ...        ...
# 3895  Female         Hoodie     Clothing       Virginia    L  Turquoise
# 3896  Female       Backpack  Accessories           Iowa    L      White
# 3897  Female           Belt  Accessories     New Jersey    L      Green
# 3898  Female          Shoes     Footwear      Minnesota    S      Brown
# 3899  Female        Handbag  Accessories     California    M      Beige
#
#       Season Subscription_Status   Shipping_Type Discount_Applied  \
# ...

# %%
for i in obj:
    df[i] = df[i].fillna(df[i].mode()[0])
    print(df[i])
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 3895    Female
# 3896    Female
# 3897    Female
# 3898    Female
# 3899    Female
# Name: Gender, Length: 3900, dtype: object
# 0         Blouse
# 1        Sweater
# 2          Jeans
# 3        Sandals
# 4         Blouse
#           ...
# 3895      Hoodie
# 3896    Backpack
# 3897        Belt
# 3898       Shoes
# 3899     Handbag
# Name: Item_Purchased, Length: 3900, dtype: object
# 0          Clothing
# 1          Clothing
# 2          Clothing
# 3          Footwear
# 4          Clothing
#            ...
# 3895       Clothing
# 3896    Accessories
# 3897    Accessories
# 3898       Footwear
# 3899    Accessories
# Name: Category, Length: 3900, dtype: object
# 0            Kentucky
# 1               Maine
# 2       Massachusetts
# 3        Rhode Island
# 4              Oregon
#             ...
# 3895         Virginia
# 3896             Iowa
# 3897       New Jersey
# ...

# %%
df.isna().sum()
# Out:
# Customer_id               0
# Age                       0
# Gender                    0
# Item_Purchased            0
# Category                  0
# Purchase_Amount_USD       0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review_Rating             0
# Subscription_Status       0
# Shipping_Type             0
# Discount_Applied          0
# Promo_Code_Used           0
# Previous_Purchases        0
# Payment_Method            0
# Frequency_of_Purchases    0
# dtype: int64

# %%
df.to_csv(r"D:\SLA\Python\customer_data.csv",index = False)

# %%
df = pd.read_csv(r"D:\SLA\Python\customer_data.csv")
df
# Out:
#       Customer_id  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                    53.0       Kentucky    L       Gray  Winter
# 1                    64.0          Maine    L     Maroon  Winter
# ...

# %%
plt.figure(figsize= (10,7))
box = []
data =['Purchase_Amount_USD', 'Review_Rating', 'Previous_Purchases']
mycolors = ['red','green','pink']
for b in data:
    box.append(df[b])
plt.boxplot(box,patch_artist = True)
plt.xticks(range(1,len(data)+1),data,color = "Black")
plt.show()

# %%
df.isna().sum()
# Out:
# Customer_id               0
# Age                       0
# Gender                    0
# Item_Purchased            0
# Category                  0
# Purchase_Amount_USD       0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review_Rating             0
# Subscription_Status       0
# Shipping_Type             0
# Discount_Applied          0
# Promo_Code_Used           0
# Previous_Purchases        0
# Payment_Method            0
# Frequency_of_Purchases    0
# dtype: int64
